# %% [markdown]
# # THE SPARKS FOUNDATION

# %% [markdown]
# # GRIP TASK 4: EXPLORATORY DATA ANALYSIS ON GLOBAL TERRORISM

# %% [markdown]
# Perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’
#
# ● As a security/defense analyst, try to find out the hot zone of terrorism.
#
# ● What all security issues and insights you can derive by EDA?

# %% [markdown]
# # AUTHOR: JAGATH BHASI

# %% [markdown]
# IMPORTING LIBRARY

# %%
#importing the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# IMPORTING DATA

# %%
# Let's import to our data and check the basics.
data = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
# Out:
# C:\Users\Public\anacon\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %% [markdown]
# # Terrorist Activities by Region in each Year through Area Plot

# %%
pd.crosstab(data.iyear, data.region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# # Plotting Countries vs Attacks

# %%
#Plotting Countries vs Attacks
data['country'].value_counts()
plt.figure(figsize=(20,8))
plt.style.use('dark_background')
sns.barplot(x=data['country_txt'].value_counts()[:20].index,y=data['country_txt'].value_counts()[:20].values)
plt.title('COUNTRIES ATTACKED')
plt.xticks(rotation=40)
plt.xlabel('Country')
plt.ylabel('Attacks')
plt.show()

# %% [markdown]
# # Plotting Regions vs Attacks

# %%
#Plotting Regions vs Attacks
data['region_txt'].value_counts()
plt.figure(figsize=(20,8))
sns.countplot(x='region_txt',data=data)
plt.xticks(rotation=40)
plt.title('REGIONS ATTACKED')
plt.ylabel('Attacks')
plt.xlabel('Regions')
plt.show()

# %%
#counting the number of cities in the dataset
data['city'].value_counts()
# Out:
# Unknown       9775
# Baghdad       7589
# Karachi       2652
# Lima          2359
# Mosul         2265
#               ...
# Artabueror       1
# Hardumadam       1
# Sar Rustaq       1
# Bishoftu         1
# Cedro            1
# Name: city, Length: 36674, dtype: int64

# %% [markdown]
# # Plotting Year vs Attacks

# %%
#Plotting Year vs Attacks
plt.subplots(figsize=(15,10))
sns.countplot(x='iyear',data=data,palette='tab10')
plt.xticks(rotation=60)
plt.title('TERROR ATTACKS YEARLY')
plt.ylabel('Attacks')
plt.xlabel('Year')
plt.show()

# %%
#Plotting Attack Type vs Attacks
plt.figure(figsize=(15,8))
sns.countplot(x=data['attacktype1_txt'],order=data['attacktype1_txt'].value_counts().index,palette='rainbow')
plt.xticks(rotation=40)
plt.title('ATTACKS OF DIFFERENT TYPES')
plt.xlabel('Attack Type')
plt.ylabel('Attacks')
plt.show()

# %% [markdown]
# # Plotting Groups vs it's Attacks

# %%
#Plotting Groups vs it's Attacks
plt.figure(figsize=(20,8))
sns.barplot(x=data['gname'].value_counts()[:20].index,y=data['gname'].value_counts()[:20].values,palette='pastel')
plt.xticks(rotation=90)
plt.title('GROUPS ATTACKED')
plt.xlabel('Group')
plt.ylabel('Attacks')
plt.show()

# %% [markdown]
# # Plotting City vs it's Attacks

# %%
#Plotting City vs it's Attacks
data['city'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(x=data['city'].value_counts()[:20].index,y=data['city'].value_counts()[:20].values, palette = "tab10")
plt.title('CITIES ATTACKED')
plt.xticks(rotation=40)
plt.xlabel('City')
plt.ylabel('Attacks')
plt.show()

# %%
#Plotting Weapons vs it's Frequency
data['weaptype1_txt'].value_counts()
plt.figure(figsize=(20,12))
color=['lightblue','red','lightpink','brown']
sns.barplot(x=data['weaptype1_txt'].value_counts()[:20].index,y=data['weaptype1_txt'].value_counts()[:20].values , palette = "pastel")
plt.title('FREQUENCY OF WEAPONS USED')
plt.xticks(rotation=90)
plt.xlabel('Weapons')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# OBSERVATIONS:
# -> IRAN and PAKISTAN are most attacked countries.
#
# -> MIDDLE EAST & NORTH AFRICA and SOUTH ASIA are most attacked regions.
#
# -> There was growth in terrorist attack form 1977 to 1980 and a huge growth from 2000 to 2014.
#
# -> BOMBING/EXPLOSION and ARMED ASSSAULT are most used attack type by terrorists.
#
# -> MILITARY and PRIVATE CITIZEN & PROPERTY were most targeted during terrorist attacks.
#
# -> Most number of attacks were done by UNKNOWN GROUP among the group of terrorists.
#
# -> UNKNOWN and BAGHDAD are the most attacked cities.
